# %%
import numpy as np
import astropy
import scipy 
import pylab as plt
from blimpy import Waterfall

# %%
# %matplotlib inline

# %%
# !wget http://blpd0.ssl.berkeley.edu/Voyager_data/Voyager1.single_coarse.fine_res.h5
# Out:
# --2021-09-15 22:35:21--  http://blpd0.ssl.berkeley.edu/Voyager_data/Voyager1.single_coarse.fine_res.h5
# Resolving blpd0.ssl.berkeley.edu (blpd0.ssl.berkeley.edu)... 208.68.240.101
# Connecting to blpd0.ssl.berkeley.edu (blpd0.ssl.berkeley.edu)|208.68.240.101|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 50549227 (48M) [application/octet-stream]
# Saving to: ‘Voyager1.single_coarse.fine_res.h5’
#
# Voyager1.single_coa 100%[===================>]  48.21M  4.33MB/s    in 23s
#
# 2021-09-15 22:35:47 (2.14 MB/s) - ‘Voyager1.single_coarse.fine_res.h5’ saved [50549227/50549227]

# %%
file_path = 'Voyager1.single_coarse.fine_res.h5'
obs = Waterfall(file_path)

# %%
obs.plot_waterfall(f_start= 8419.274, f_stop=8419.275)
